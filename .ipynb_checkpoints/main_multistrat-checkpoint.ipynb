# %% [markdown]
# # 1. Import packages

# %% [markdown]
# First import standard packages and modules

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
from pykalman import KalmanFilter

# %% [markdown]
# Then import the self-defined modules

# %%
from my_helper_fn import *
from myStrategies.regression import RegressionLongShort
from myStrategies.kalmanfilter import RegressionKalmanFilter

# %% [markdown]
# # 2. Read in Yahoo Finance stock data stored in csv files.

# %% [markdown]
# Read stock prices from 2000 through 2015

# %%
price_csv = 'stock_adj_close_2000_2015.csv';
stock_prices = read_from_csv( price_csv );
monthly_stock_prices = stock_prices.resample( "BM" ).last();
monthly_stock_returns = monthly_stock_prices.pct_change().iloc[1:];

# %% [markdown]
# Then read S&P Index as benchmark and Treasury 3-month bond interest rate as risk-free rate. Note that the bond interest rate is annualized figure when downloaded, and therefore it needs to be converted to monthly rate in order to be compared with monthly stock return.

# %%
snp_500 = read_from_csv( "benchmark.csv" );
snp_500 = snp_500.resample( "BM" ).last();
snp_500_returns = snp_500.pct_change().iloc[1:];
benchmark_returns = snp_500_returns;

rf_annualized_rate = read_from_csv( "riskfree.csv", rescale_factor = 0.01 );
def deannualization_func( annual_rate, freq="M" ):
	if freq is "M":
		return (1+annual_rate)**(1/12) - 1

rf_rate = rf_monthly_rate = rf_annualized_rate.apply( deannualization_func );
riskfree_rate = rf_rate;

# %% [markdown]
# # Now create instances of self-defined strategies

# %% [markdown]
# Strategy 1: rank stocks using autoregression with lookback window of fixed size

# %%
reg_lags_and_weights = { 1:1 };    #Look back window has size 1; simplest case and yet generate expected results
strategy_longshort = RegressionLongShort( 
						stock_prices,
						riskfree_rate,
						benchmark_returns,
						resample_freq = "BM",
						sample_lookback = 60,			# number of periods of looking back for training data
						reg_lags_and_weights = reg_lags_and_weights,
						num_longs = 10,					# number of stocks to long for each period
						num_shorts = 0,				# number of stocks to short for each period
);
longshort_backtest = strategy_longshort.BackTest();
longshort_backtest_analysis = strategy_longshort.BackTestAnalysis();
print longshort_backtest_analysis;
# Out:
# {'Average Return': 0.012191304764512556, 'Sortino': 0.070450008611453493, 'CAMP': (0.0044970618337096674, 1.4200280542474772), 'Sharpe': 0.53926796455014692, 'Info_Ratio': 0.43531326656491881, 'Volatility': 0.08001407420333452}

# %% [markdown]
# Strategy 2: using Kalman Filter to dynamically adjust first-order autoregression coefficient

# %%
# 2.2 RegressionKalmanFilter
strategy_kalmanfilter = RegressionKalmanFilter(
				stock_prices,
				riskfree_rate,
				benchmark_returns,
				resample_freq = "BM",
				num_longs = 10,					# number of stocks to long for each period
				num_shorts = 0,				# number of stocks to short for each period
);

kf_backtest = strategy_kalmanfilter.BackTest();
kf_backtest_analysis = strategy_kalmanfilter.BackTestAnalysis();
print kf_backtest_analysis
# Out:
# Example of obs_mat is  [[[-0.14389654  1.        ]
#   [-0.16039157  1.        ]
#   [ 0.00911841  1.        ]
#   ...,
#   [-0.25566964  1.        ]
#   [-0.25889964  1.        ]
#   [ 0.00438192  1.        ]]
#
#  [[ 0.56940522  1.        ]
#   [-0.0136213   1.        ]
#   [ 0.10481945  1.        ]
#   ...,
#   [-0.00834456  1.        ]
#   [-0.06986895  1.        ]
#   [-0.10253701  1.        ]]]
# {'Average Return': 0.017710560689533462, 'Sortino': 0.075121706300949831, 'CAMP': (0.011658336844379176, 1.5838990845095509), 'Sharpe': 0.60509193946627415, 'Info_Ratio': 0.71708547211337925, 'Volatility': 0.095864748658792548}

# %% [markdown]
# # Compare strategies with plots

# %% [markdown]
# Get the cumulative return for a common period

# %%
common_start = max( longshort_backtest["overall"].index[0], kf_backtest["overall"].index[0] );
ls_monthly = longshort_backtest["overall"].loc[ common_start:];
kf_monthly = kf_backtest[ "overall" ].loc[common_start:];
ls_cum_returns = (1 + ls_monthly ).cumprod();
kf_cum_returns = (1 + kf_monthly ).cumprod();

# %% [markdown]
# First plot and compare monthly returns between two strategies

# %%
fig1 = plt.figure(1);
plt.plot( ls_monthly.index, ls_monthly.values, label = "Autoregression with\nfixed-size moving window" );
plt.plot( kf_monthly.index, kf_monthly.values, label = "Kalman Filter" );
plt.xlabel( "Date" );
plt.ylabel( "Monthly Returns" );
plt.title( "Monthly Returns of Strategies" );
plt.legend();
fig1;

# %% [markdown]
# Next plot and compare the cumulative monthly returns between two strategies

# %%
fig2 = plt.figure(2);
plt.plot( ls_cum_returns.index, ls_cum_returns.values, label = "Autoregression with\nfixed-size moving window" );
plt.plot( kf_cum_returns.index, kf_cum_returns.values, label = "Kalman Filter" );
plt.xlabel( "Date" );
plt.ylabel( "Cumulative Returns" );
plt.title( "Cumulative Returns of Strategies" );
plt.legend();
fig2;
